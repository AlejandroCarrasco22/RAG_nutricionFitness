# %% [markdown]
# ## Bases de datos

# %%
# SQL (creación y consulta de base de datos relacional local)
# !pip install sqlalchemy sqlite-utils

# Soporte para archivos Excel (.xlsx)
# !pip install openpyxl pandas

# !pip install fuzzywuzzy python-Levenshtein

# %%
file_name = "food_cleaned.csv"
file_path = f"../data/csv/{file_name}"
import pandas as pd
import os
import sqlite3

if not os.path.exists(file_path):
    raise FileNotFoundError(f"Archivo no encontrado: {file_path}")

df = pd.read_csv(file_path)

# Conexión a una base de datos local SQLite
conn = sqlite3.connect("../comida.db")
df.to_sql("comida", conn, if_exists="replace", index=False)

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("../comida.db")
consulta_sql = pd.read_sql( 'SELECT * FROM comida LIMIT 5', conn)

# %%
consulta_sql
# Out:
#   category                     description  alpha_carotene  beta_carotene  \
# 0     Milk                     Milk, human             0.0            7.0
# 1     Milk                       Milk, NFS             0.0            4.0
# 2     Milk                     Milk, whole             0.0            7.0
# 3     Milk         Milk, low sodium, whole             0.0            7.0
# 4     Milk  Milk, calcium fortified, whole             0.0            7.0
#
#    beta_cryptoxanthin  carbohydrate  cholesterol  choline  fiber  \
# 0                 0.0          6.89         14.0     16.0    0.0
# 1                 0.0          4.87          8.0     17.9    0.0
# 2                 0.0          4.67         12.0     17.8    0.0
# 3                 0.0          4.46         14.0     16.0    0.0
# 4                 0.0          4.67         12.0     17.8    0.0
#
#    lutein_and_zeaxanthin  ...  major_minerals.potassium  \
# 0                    0.0  ...                      51.0
# 1                    0.0  ...                     157.0
# 2                    0.0  ...                     150.0
# 3                    0.0  ...                     253.0
# 4                    0.0  ...                     150.0
#
#    major_minerals.sodium  major_minerals.zinc  vitamins.vitamin_a_-_rae  \
# 0                   17.0                 0.17                      61.0
# 1                   39.0                 0.42                      59.0
# 2                   38.0                 0.41                      32.0
# 3                    3.0                 0.38                      29.0
# 4                   38.0                 0.41                      32.0
#
#    vitamins.vitamin_b12  vitamins.vitamin_b6  vitamins.vitamin_c  \
# 0                  0.05                0.011                 5.0
# 1                  0.56                0.060                 0.1
# 2                  0.54                0.061                 0.0
# 3                  0.36                0.034                 0.9
# 4                  0.54                0.061                 0.0
#
#    vitamins.vitamin_e  vitamins.vitamin_k  calories
# 0                0.08                 0.3     71.10
# 1                0.03                 0.2     50.75
# 2                0.05                 0.3     60.60
# 3                0.08                 0.3     61.38
# 4                0.05                 0.3     60.60
#
# [5 rows x 38 columns]

# %%
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain_community.llms import OpenAI # Asegúrate de que esta importación sea correcta según tu setup
from langchain.chains import LLMChain
import sqlite3
import pandas as pd
from fuzzywuzzy import process

import os
import sys
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(parent_dir)
from keys import LLM

llm = LLM

sql_system_prompt = SystemMessagePromptTemplate.from_template(
    """Eres un asistente experto en bases de datos SQLite.

Tu tarea es generar **ÚNICAMENTE una query SQL válida**, sin explicaciones, sin texto adicional y sin formato markdown (como triples comillas ```, la palabra 'sql', o cualquier otro envoltorio), a partir de una pregunta del usuario.

Trabajas con una tabla llamada `comida`, el contenido de las tablas de texto viene en inglés, con las siguientes columnas. **¡IMPORTANTE! Cuando uses los nombres de las columnas que contienen puntos o guiones, DEBES ENVOLVERLOS ENTRE COMILLAS DOBLES (")** para que la consulta sea válida en SQLite.

- "category" (TEXT) - Categoría general del alimento. **Contiene una gran variedad de valores únicos.**
- "description" (TEXT) - Descripción completa del alimento y sus subcategorías (ej. 'Milk, human', 'Buttermilk, low fat (1%)').
- "alpha_carotene" (REAL) - Pigmento vegetal. Unidad: microgramos (mcg).
- "beta_carotene" (REAL) - Pigmento vegetal. Unidad: microgramos (mcg).
- "beta_cryptoxanthin" (REAL) - Pigmento vegetal. Unidad: microgramos (mcg).
- "carbohydrate" (REAL) - Azúcares y almidones. Unidad: gramos (g).
- "cholesterol" (REAL) - Presente solo en productos animales. Unidad: miligramos (mg).
- "choline" (REAL) - Nutriente esencial. Unidad: miligramos (mg).
- "fiber" (REAL) - Parte vegetal no digerible. Unidad: gramos (g).
- "lutein_and_zeaxanthin" (REAL) - Pigmento vegetal. Unidad: microgramos (mcg).
- "lycopene" (REAL) - Pigmento vegetal. Unidad: microgramos (mcg).
- "niacin" (REAL) - Vitamina B. Unidad: miligramos (mg).
- "protein" (REAL) - Esencial para tejidos. Unidad: gramos (g).
- "retinol" (REAL) - Vitamina A activa. Unidad: microgramos (mcg).
- "riboflavin" (REAL) - Vitamina B. Unidad: miligramos (mg).
- "selenium" (REAL) - Antioxidante. Unidad: microgramos (mcg).
- "sugar_total" (REAL) - Azúcares simples. Unidad: gramos (g).
- "thiamin" (REAL) - Vitamina B. Unidad: miligramos (mg).
- "water" (REAL) - Cantidad de agua. Unidad: gramos (g).
- "fat.monosaturated_fat" (REAL) - Grasas monoinsaturadas. Unidad: gramos (g).
- "fat.polysaturated_fat" (REAL) - Grasas poliinsaturadas. Unidad: gramos (g).
- "fat.saturated_fat" (REAL) - Grasas saturadas. Unidad: gramos (g).
- "fat.total_lipid" (REAL) - Suma de todas las grasas. Unidad: gramos (g).
- "major_minerals.calcium" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.copper" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.iron" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.magnesium" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.phosphorus" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.potassium" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.sodium" (REAL) - Mineral. Unidad: miligramos (mg).
- "major_minerals.zinc" (REAL) - Mineral. Unidad: miligramos (mg).
- "vitamins.vitamin_a_-_rae" (REAL) - Vitamina A. Unidad: microgramos (mcg).
- "vitamins.vitamin_b12" (REAL) - Vitamina B12. Unidad: microgramos (mcg).
- "vitamins.vitamin_b6" (REAL) - Vitamina B6. Unidad: miligramos (mg).
- "vitamins.vitamin_c" (REAL) - Vitamina C. Unidad: miligramos (mg).
- "vitamins.vitamin_e" (REAL) - Vitamina E. Unidad: miligramoscg).
- "vitamins.vitamin_k" (REAL) - Vitamina K. Unidad: microgramos (mcg).
- "calories" (REAL) - Calorías por 100g.

GUIDELINES:

**1. Cuando una columna específica (como calorías, proteína, etc.) sea solicitada, SIEMPRE incluye también las columnas "category" y "description" en la cláusula SELECT.**
**2. Para preguntas que solicitan una propiedad general (ej. "alimentos con X calorías", "alimentos con más Y"), enfócate en la condición numérica o de ordenación en el WHERE/ORDER BY. Solo usa filtros de "category" o "description" (LIKE) si la pregunta especifica un TIPO de alimento a buscar.**
**3. Devuelve ÚNICAMENTE una consulta SQL válida. No incluyas ningún texto extra, explicaciones o formato markdown (como triples comillas ```, la palabra 'sql', o cualquier otro envoltorio).**
**4. Para filtrar por alimentos específicos, usa la columna "description" con el operador LIKE y el texto del alimento CAPITALIZADO (Camel Case) en inglés, dado que la base de datos está en inglés, por ejemplo: LIKE '%Chicken Breast%' o LIKE '%Avocado%'.**
**5. Para filtrar por categorías generales de alimentos, usa la columna "category" con el operador '=' y el valor exacto de la categoría (en Camel Case) en inglés.**
**6. Recuerda que los nombres de las columnas que contienen puntos o guiones DEBEN ENVOLVERSE ENTRE COMILLAS DOBLES (") en la consulta SQL (ej. "fat.total_lipid", "vitamins.vitamin_a_-_rae").**
"""
)

sql_human_prompt = HumanMessagePromptTemplate.from_template(
    """{contexto}
    Pregunta: {pregunta}
    """
)

sql_prompt = ChatPromptTemplate.from_messages([
    sql_system_prompt,
    sql_human_prompt
])


sql_chain = LLMChain(llm=llm, prompt=sql_prompt)
# Out:
# C:\Users\asusg\AppData\Local\Temp\ipykernel_17868\2661594649.py:86: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   sql_chain = LLMChain(llm=llm, prompt=sql_prompt)

# %% [markdown]
# ### Filtrar las categorias en las que puede buscar
#
# Ahora, antes de generar las busquedas, voy a guardar las categorias de comida.db para ofrecerle un contecto
# mucho más completo al LLM

# %%
DATABASE_PATH = "../comida.db"

translator_system_prompt = SystemMessagePromptTemplate.from_template(
    "Traduce el siguiente término de alimento o categoría del español a su equivalente en inglés más común, adecuado para una consulta de base de datos. Responde ÚNICAMENTE con el término en inglés, sin explicaciones ni texto adicional."
)
translator_human_prompt = HumanMessagePromptTemplate.from_template("{term_spanish}")
translator_prompt = ChatPromptTemplate.from_messages([
    translator_system_prompt,
    translator_human_prompt
])

translator_chain = LLMChain(llm=llm, prompt=translator_prompt)

def get_unique_categories(db_path):
    """Carga todas las categorías únicas de la base de datos."""
    conn = sqlite3.connect(db_path)
    try:
        query = 'SELECT DISTINCT "category" FROM comida'
        categories_df = pd.read_sql_query(query, conn)
        return categories_df["category"].tolist()
    except Exception as e:
        print(f"Error al cargar categorías: {e}")
        return []
    finally:
        conn.close()

# Cargar las categorías al inicio de tu script/aplicación
# Esto se ejecutaría una sola vez
unique_categories = get_unique_categories(DATABASE_PATH)

# %%
unique_categories
# Out:
# ['Milk',
#  'Buttermilk',
#  'Kefir',
#  "Goat's milk",
#  'Non-dairy milk',
#  'Soy milk',
#  'Almond milk',
#  'Rice milk',
#  'Coconut milk',
#  'Yogurt',
#  'Chipotle dip',
#  'Dill dip',
#  'Onion dip',
#  'Ranch dip',
#  'Spinach dip',
#  'Tzatziki dip',
#  'Vegetable dip',
#  'Yogurt parfait',
#  'Frozen yogurt',
#  'Frozen yogurt sandwich',
#  'Frozen yogurt bar',
#  'Frozen yogurt cone',
#  'Chocolate milk',
#  'Hot chocolate / Cocoa',
#  'Strawberry milk',
#  'Eggnog',
#  'Milk shake',
#  'Milk shake with malt',
#  'Licuado or Batido',
#  'Fruit smoothie',
#  'Fruit smoothie juice drink',
#  'Chocolate milk drink',
#  'Infant formula',
#  'Whey',
#  'Cocoa powder',
#  'Chocolate beverage powder',
#  'Strawberry beverage powder',
#  'Cream',
#  'Coffee creamer',
#  'Whipped topping',
#  'Sour cream',
#  'Dip',
#  'Ice cream',
#  'Gelato',
#  'Ice cream bar',
#  'Ice cream candy bar',
#  'Ice cream sandwich',
#  'Ice cream cookie sandwich',
#  'Ice cream cone',
#  'Ice cream soda',
#  'Ice cream sundae',
#  'Banana split',
#  'Light ice cream',
#  'Soft serve',
#  'Light ice cream sandwich',
#  'Light ice cream bar',
#  'Creamsicle',
#  'Fudgesicle',
#  'Light ice cream cone',
#  'Sherbet',
#  'Pudding',
#  'Custard',
#  'Flan',
#  'Creme brulee',
#  'Firni',
#  'Banana pudding',
#  'Mousse',
#  'Milk dessert or milk candy',
#  'Barfi or Burfi',
#  'Trifle',
#  'Tiramisu',
#  'Custard pudding',
#  'White sauce or gravy',
#  'Cheese',
#  'Queso Anejo',
#  'Queso Asadero',
#  'Queso Fresco',
#  'Queso cotija',
#  'Cottage cheese',
#  'Puerto Rican white cheese',
#  'Cream cheese',
#  'Cheese spread',
#  'Cream cheese spread',
#  'Imitation cheese',
#  'Cheese ball',
#  'Artichoke dip',
#  'Spinach and artichoke dip',
#  'Seafood dip',
#  'Cheese dip with chili pepper',
#  'Cheese dip',
#  'Topping from cheese pizza',
#  'Topping from vegetable pizza',
#  'Topping from meat pizza',
#  'Topping from meat and vegetable pizza',
#  'Cheese fondue',
#  'Cheese souffle',
#  'Welsh rarebit',
#  'Cheese sandwich',
#  'Grilled cheese sandwich',
#  'Cheese sauce',
#  'Alfredo sauce',
#  'Alfredo sauce with added vegetables',
#  'Alfredo sauce with meat',
#  'Alfredo sauce with meat and added vegetables',
#  'Alfredo sauce with poultry',
#  'Alfredo sauce with poultry and added vegetables',
#  'Alfredo sauce with seafood',
#  'Alfredo sauce with seafood and added vegetables',
#  'Mozzarella sticks',
#  'Mozzarella cheese',
#  'Cheddar cheese soup',
#  'Beer cheese soup',
#  'Meat',
#  'Meat sticks',
#  'Ground meat',
#  'Beef',
#  'Steak',
#  'Beef steak',
#  'Corned beef',
#  'Beef brisket',
#  'Ground beef',
#  'Ground beef patty',
#  'Beef jerky',
#  'Pork',
#  'Pork jerky',
#  'Pork chop',
#  'Pork steak or cutlet',
#  'Ham',
#  'Pork roast',
#  'Fried pork chunks',
#  'Pork roll',
#  'Canadian bacon',
#  'Bacon',
#  'Pork bacon',
#  'Bacon or side pork',
#  'Salt pork',
#  'Fat back',
#  'Pork ears',
#  'Pork skin rinds',
#  'Pork skin',
#  'Meat stick',
#  'Lamb',
#  'Lamb chop',
#  'Lamb hocks',
#  'Goat',
#  'Goat head',
#  'Goat ribs',
#  'Veal',
#  'Veal chop',
#  'Veal cutlet or steak',
#  'Mock chicken legs',
#  'Veal patty',
#  'Rabbit',
#  'Venison/deer',
#  'Venison/deer steak',
#  'Venison/deer jerky',
#  'Deer sausage',
#  'Deer chop',
#  'Venison/deer ribs',
#  'Moose',
#  'Bear',
#  'Caribou',
#  'Bison',
#  'Ground hog',
#  'Opossum',
#  'Squirrel',
#  'Beaver',
#  'Raccoon',
#  'Armadillo',
#  'Wild pig',
#  'Ostrich',
#  'Chicken',
#  'Chicken breast',
#  'Chicken leg',
#  'Chicken drumstick',
#  'Chicken thigh',
#  'Chicken wing',
#  'Chicken "wings" with hot sauce',
#  'Chicken "wings" with other sauces or seasoning',
#  'Chicken "wings"',
#  'Chicken skin',
#  'Chicken feet',
#  'Chicken patty',
#  'Chicken fillet',
#  'Chicken nuggets',
#  'Chicken tenders or strips',
#  'Fried chicken chunks',
#  'Turkey',
#  'Turkey light or dark meat',
#  'Turkey bacon',
#  'Turkey with barbecue sauce',
#  'Duck',
#  'Goose',
#  'Cornish game hen',
#  'Dove',
#  'Quail',
#  'Pheasant',
#  'Chicken stick',
#  'Turkey stick',
#  'Beef liver',
#  'Chicken liver',
#  'Liver paste or pate',
#  'Heart',
#  'Kidney',
#  'Sweetbreads',
#  'Brains',
#  'Tongue',
#  'Tongue pot roast',
#  'Tripe',
#  'Chitterlings',
#  'Hog maws',
#  'Gizzard',
#  'Frankfurter or hot dog',
#  'Beef sausage',
#  'Beef sausage with cheese',
#  'Blood sausage',
#  'Bratwurst',
#  'Bologna',
#  'Turkey or chicken and beef sausage',
#  'Chorizo',
#  'Head cheese',
#  'Knockwurst',
#  'Mortadella',
#  'Pastrami',
#  'Pepperoni',
#  'Polish sausage',
#  'Italian sausage',
#  'Sausage',
#  'Pork sausage',
#  'Pork sausage rice links',
#  'Pork and beef sausage',
#  'Salami',
#  'Scrapple',
#  'Thuringer',
#  'Turkey or chicken sausage',
#  'Turkey or chicken and pork sausage',
#  'Turkey or chicken',
#  'Vienna sausage',
#  'Pickled sausage',
#  'Luncheon meat',
#  'Ham luncheon meat',
#  'Ham and pork',
#  'Liverwurst',
#  'Turkey ham',
#  'Meat spread or potted meat',
#  'Chicken salad spread',
#  'Ham salad spread',
#  'Fish',
#  'Fish stick',
#  'Anchovy',
#  'Barracuda',
#  'Carp',
#  'Catfish',
#  'Cod',
#  'Croaker',
#  'Eel',
#  'Flounder',
#  'Haddock',
#  'Halibut',
#  'Herring',
#  'Mackerel',
#  'Mullet',
#  'Ocean perch',
#  'Perch',
#  'Pike',
#  'Pompano',
#  'Porgy',
#  'Ray',
#  'Salmon',
#  'Sardines',
#  'Sea bass',
#  'Shark',
#  'Sturgeon',
#  'Swordfish',
#  'Trout',
#  'Tuna',
#  'Whiting',
#  'Tilapia',
#  'Frog legs',
#  'Octopus',
#  'Roe',
#  'Squid',
#  'Turtle',
#  'Abalone',
#  'Clams',
#  'Crab',
#  'Crayfish',
#  'Lobster',
#  'Mussels',
#  'Oysters',
#  'Scallops',
#  'Shrimp',
#  'Snails',
#  'Beef with tomato-based sauce',
#  'Beef goulash',
#  'Beef burgundy',
#  'Beef stew',
#  'Chili con carne',
#  'Chili con carne with beans',
#  'Chili con carne without beans',
#  'Chili con carne with beans and cheese',
#  'Beef sloppy joe',
#  'Beef with gravy',
#  'Salisbury steak with gravy',
#  'Beef with cream or white sauce',
#  'Beef stroganoff',
#  'Creamed chipped or dried beef',
#  'Swedish meatballs with cream or white sauce',
#  'Beef with mushroom sauce',
#  'Beef with soy-based sauce',
#  'Steak teriyaki',
#  'Beef curry',
#  'Beef curry with rice',
#  'Beef with barbecue sauce',
#  'Beef with sweet and sour sauce',
#  'Stewed seasoned ground beef',
#  'Steak tartare',
#  'Meatballs',
#  'Stewed dried beef',
#  'Stuffed pot roast',
#  'Ham or pork with gravy',
#  'Ham or pork with barbecue sauce',
#  'Sweet and sour pork',
#  'Ham stroganoff',
#  'Ham or pork with mushroom sauce',
#  'Ham or pork with tomato-based sauce',
#  'Sausage with tomato-based sauce',
#  'Sausage gravy',
#  'Pork stew',
#  'Pork or ham with soy-based sauce',
#  'Frankfurters or hot dogs with tomato-based sauce',
#  'Pork with chili and tomatoes',
#  'Stewed pork',
#  'Lamb or mutton with gravy',
#  'Lamb or mutton goulash',
#  'Stewed goat',
#  'Veal with gravy',
#  'Veal scallopini',
#  'Veal with cream sauce',
#  'Veal with butter sauce',
#  'Veal Marsala',
#  'Veal parmigiana',
#  'Veal cordon bleu',
#  'Venison or deer with tomato-based sauce',
#  'Venison or deer with gravy',
#  'Chili con carne with venison/deer and beans',
#  'Chicken or turkey cacciatore',
#  'Spaghetti sauce with poultry',
#  'Spaghetti sauce with poultry and added vegetables',
#  'Stewed chicken with tomato-based sauce',
#  'Chili con carne with chicken or turkey and beans',
#  'Chicken with gravy',
#  'Chicken or turkey fricassee',
#  'Turkey with gravy',
#  'Chicken or turkey with cream sauce',
#  'Chicken or turkey with mushroom sauce',
#  'Chicken or turkey with teriyaki',
#  'Sweet and sour chicken or turkey',
#  'Chicken curry',
#  'Chicken curry with rice',
#  'Chicken with mole sauce',
#  'Chicken or turkey with cheese sauce',
#  'Chicken or turkey cordon bleu',
#  'Chicken or turkey parmigiana',
#  'Orange chicken',
#  'Sesame chicken',
#  'Chicken kiev',
#  'Stuffed chicken',
#  'Fish with cream or white sauce',
#  'Crab imperial',
#  'Fish timbale or mousse',
#  'Lobster newburg',
#  'Lobster with butter sauce',
#  'Shrimp cocktail',
#  'Tuna with cream or white sauce',
#  'Seafood newburg',
#  'Seafood sauce',
#  'Spaghetti sauce with seafood',
#  'Spaghetti sauce with seafood and added vegetables',
#  'Shrimp with lobster sauce',
#  'Sweet and sour shrimp',
#  'Fish sauce',
#  'Shrimp scampi',
#  'Fish moochim',
#  'Fish with tomato-based sauce',
#  'Fish curry',
#  'Fish curry with rice',
#  'Mussels with tomato-based sauce',
#  'Sardines with tomato-based sauce',
#  'Sardines with mustard sauce',
#  'Shrimp teriyaki',
#  'Scallops with cheese sauce',
#  'Ceviche',
#  'Crabs in tomato-based sauce',
#  'Shrimp in garlic sauce',
#  'Stewed codfish',
#  'Meat with barbecue sauce',
#  'Meat loaf',
#  'Meat with tomato-based sauce',
#  'Spaghetti sauce with meat',
#  'Spaghetti sauce with meat and added vegetables',
#  'Stewed',
#  'Meat with gravy',
#  'Beef and potatoes',
#  'Beef stew with potatoes',
#  'Beef goulash with potatoes',
#  'Beef and potatoes with cream sauce',
#  'Corned beef hash',
#  'Beef and potatoes with cheese sauce',
#  'Beef and noodles',
#  'Beef and macaroni with cheese sauce',
#  'Beef and noodles with tomato-based sauce',
#  'Chili con carne with beans and macaroni',
#  'Beef goulash with noodles',
#  'Beef and noodles with gravy',
#  'Beef and noodles with cream or white sauce',
#  'Beef stroganoff with noodles',
#  'Beef and noodles with mushroom sauce',
#  'Beef and noodles with soy-based sauce',
#  'Beef and rice',
#  'Biryani with meat',
#  'Beef and rice with tomato-based sauce',
#  'Porcupine balls with tomato-based sauce',
#  'Chili con carne with beans and rice',
#  'Beef and rice with gravy',
#  'Beef and rice with cream sauce',
#  'Beef and rice with mushroom sauce',
#  'Porcupine balls with mushroom sauce',
#  'Beef and rice with soy-based sauce',
#  'Beef and rice with cheese sauce',
#  'Meat loaf made with beef',
#  'Beef wellington',
#  'Corned beef patty',
#  'Stewed corned beef',
#  'Meat loaf made with ham',
#  'Ham and noodles with cream or white sauce',
#  'Ham and rice with mushroom sauce',
#  'Ham or pork with stuffing',
#  'Ham croquette',
#  'Pork and rice with tomato-based sauce',
#  'Sausage and rice with tomato-based sauce',
#  'Sausage and rice with mushroom sauce',
#  'Sausage and rice with cheese sauce',
#  'Sausage and noodles with cream or white sauce',
#  'Ham and noodles',
#  'Ham or pork and rice',
#  'Ham or pork and potatoes with gravy',
#  'Ham or pork and potatoes with cheese sauce',
#  "Stewed pig's feet",
#  'Stuffed pork roast',
#  'Lamb or mutton loaf',
#  'Lamb or mutton and potatoes with gravy',
#  'Lamb or mutton and potatoes with tomato-based sauce',
#  'Lamb or mutton and noodles with gravy',
#  'Meat loaf made with venison/deer',
#  'Veal and noodles with cream or white sauce',
#  'Venison or deer and noodles with cream or white sauce',
#  'Chicken or turkey hash',
#  'Chicken or turkey and potatoes with gravy',
#  'Chicken or turkey and noodles',
#  'Chicken or turkey and noodles with gravy',
#  'Chicken or turkey and noodles with mushroom sauce',
#  'Chicken or turkey and noodles with cream or white sauce',
#  'Chicken or turkey and noodles with cheese sauce',
#  'Chicken or turkey tetrazzini',
#  'Chicken or turkey and noodles with tomato-based sauce',
#  'Chicken or turkey and noodles with soy-based sauce',
#  'Chicken or turkey and rice',
#  'Biryani with chicken',
#  'Chicken or turkey and rice with cream sauce',
#  'Chicken or turkey and rice with mushroom sauce',
#  'Chicken or turkey and rice with tomato-based sauce',
#  'Chicken or turkey and rice with soy-based sauce',
#  'Chicken or turkey with dumplings',
#  'Chicken or turkey with stuffing',
#  'Chicken or turkey cake',
#  'Chicken or turkey souffle',
#  'Meat loaf made with chicken or turkey',
#  'Codfish ball or cake',
#  'Crab cake',
#  'Fish cake or patty',
#  'Gefilte fish',
#  'Salmon cake or patty',
#  'Salmon loaf',
#  'Scallops and noodles with cheese sauce',
#  'Shrimp and noodles',
#  'Shrimp and noodles with gravy',
#  'Shrimp and noodles with mushroom sauce',
#  'Shrimp and noodles with cream or white sauce',
#  'Shrimp and noodles with soy-based sauce',
#  'Shrimp and noodles with cheese sauce',
#  'Shrimp and noodles with tomato sauce',
#  'Tuna loaf',
#  'Tuna cake or patty',
#  'Clam cake or patty',
#  'Oyster fritter',
#  'Flounder with crab stuffing',
#  'Lobster with bread stuffing',
#  'Clams Casino',
#  'Mackerel cake or patty',
#  'Haddock cake or patty',
#  'Shrimp cake or patty',
#  'Shrimp with crab stuffing',
#  'Shrimp toast',
#  'Seafood restructured',
#  'Seafood souffle',
#  'Tuna noodle casserole with cream or white sauce',
#  'Tuna noodle casserole with mushroom sauce',
#  'Tuna and rice with mushroom sauce',
#  'Fish and rice with tomato-based sauce',
#  'Fish and rice with cream sauce',
#  'Fish and rice with mushroom sauce',
#  'Fish and noodles with mushroom sauce',
#  'Shellfish and noodles with tomato-based sauce',
#  'Stewed salmon',
#  'Meat loaf made with beef and pork',
#  'Hash',
#  'Vienna sausages stewed with potatoes',
#  'Liver dumpling',
#  'Breaded brains',
#  "Shepherd's pie with beef",
#  'Beef chow mein or chop suey with noodles',
#  'Stuffed cabbage rolls with beef and rice',
#  'Stuffed grape leaves with beef and rice',
#  'Beef pot pie',
#  'Stuffed green pepper',
#  'Ham pot pie',
#  'Pork chow mein or chop suey with noodles',
#  'Sweet and sour pork with rice',
#  "Shepherd's pie with lamb",
#  'Stuffed grape leaves with lamb and rice',
#  'Veal fricassee',
#  'Rabbit stew with potatoes and vegetables',
#  'Stewed rabbit',
#  'Chicken or turkey',
#  'Chicken or turkey chow mein or chop suey with noodles',
#  'Chicken or turkey pot pie',
#  'Chicken fricassee',
#  'Paella with seafood',
#  'Shrimp chow mein or chop suey with noodles',
#  'Shrimp creole',
#  'Tuna pot pie',
#  'Tuna noodle casserole with vegetables',
#  'Bouillabaisse',
#  'Oyster pie',
#  'Tuna noodle casserole with vegetables and mushroom sauce',
#  'Codfish with starchy vegetables',
#  'Biscayne codfish',
#  'Stew',
#  'Goulash',
#  'Meat pie',
#  'Chow mein or chop suey',
#  'Paella',
#  'Brunswick stew',
#  'Stewed variety meats',
#  'Stewed tripe',
#  'Gumbo with rice',
#  'Jambalaya with meat and rice',
#  'Beef shish kabob with vegetables',
#  'Swiss steak',
#  'Beef rolls',
#  'Beef and broccoli',
#  'Szechuan beef',
#  'Hunan beef',
#  'Beef chow mein or chop suey',
#  'Kung Pao beef',
#  'Beef and vegetables',
#  'Pepper steak',
#  'Beef salad',
#  'Beef taco filling: beef',
#  'Stir fried beef and vegetables in soy sauce',
#  'Seasoned shredded soup meat',
#  'Beef stew with vegetables excluding potatoes',
#  'Corned beef with tomato sauce and onion',
#  'Beef steak with onions',
#  'Cabbage with ham hocks',
#  'Ham or pork salad',
#  'Frankfurters or hot dogs and sauerkraut',
#  'Greens with ham or pork',
#  'Pork and vegetables',
#  'Pork and watercress with soy-based sauce',
#  'Kung Pao pork',
#  'Moo Shu pork',
#  'Pork and onions with soy-based sauce',
#  'Pork hash',
#  'Pork chow mein or chop suey',
#  'Sausage and peppers',
#  'Pork shish kabob with vegetables',
#  'Stuffed christophine',
#  'Pork chop stewed with vegetables',
#  'Lamb shish kabob with vegetables',
#  'Chicken or turkey shish kabob with vegetables',
#  'Chicken or turkey creole',
#  'Chicken or turkey divan',
#  'General Tso chicken',
#  'Moo Goo Gai Pan',
#  'Kung pao chicken',
#  'Almond chicken',
#  'Chicken or turkey chow mein or chop suey',
#  'Chicken or turkey salad',
#  'Chicken or turkey salad with nuts and/or fruits',
#  'Chicken or turkey salad with egg',
#  'Chicken or turkey garden salad',
#  'Chicken or turkey garden salad with bacon and cheese',
#  'Chicken or turkey garden salad with cheese',
#  'Asian chicken or turkey garden salad',
#  'Asian chicken or turkey garden salad with crispy noodles',
#  'Chicken or turkey caesar garden salad',
#  'Crab salad',
#  'Lobster salad',
#  'Salmon salad',
#  'Shrimp chow mein or chop suey',
#  'Tuna salad',
#  'Shrimp salad',
#  'Seafood salad',
#  'Tuna salad with cheese',
#  'Tuna salad with egg',
#  'Shrimp garden salad',
#  'Crab salad made with imitation crab',
#  'Seafood garden salad with seafood',
#  'Oysters Rockefeller',
#  'Lomi salmon',
#  'Shrimp shish kabob with vegetables',
#  'Kung Pao shrimp',
#  'Tuna casserole with vegetables and mushroom sauce',
#  'Fish shish kabob with vegetables',
#  'Fried fish with sauce',
#  'Lobster with sauce',
#  'Octopus salad',
#  'Codfish salad',
#  'Lau lau',
#  'Julienne salad',
#  'Antipasto with ham',
#  'Livers',
#  'Liver',
#  'Stewed chitterlings',
#  'Stewed gizzards',
#  'Gumbo',
#  'Sandwich',
#  'Meat sandwich',
#  'Wrap sandwich',
#  'Beef sandwich',
#  'Beef barbecue submarine sandwich',
#  'Cheeseburger slider',
#  'Cheeseburger',
#  'Cheeseburger (Burger King)',
#  'Whopper Jr with cheese (Burger King)',
#  'Cheeseburger (McDonalds)',
#  'Quarter Pounder (McDonalds)',
#  'Whopper with cheese (Burger King)',
#  'Quarter Pounder with cheese (McDonalds)',
#  'Cheeseburger submarine sandwich with lettuce',
#  'Double cheeseburger',
#  'Double cheeseburger (Burger King)',
#  'Double cheeseburger (McDonalds)',
#  'McDouble (McDonalds)',
#  'Big Mac (McDonalds)',
#  'Hamburger slider',
#  'Hamburger',
#  'Hamburger (Burger King)',
#  'Whopper Jr (Burger King)',
#  'Hamburger (McDonalds)',
#  'Whopper (Burger King)',
#  'Double hamburger',
#  'Meatball and spaghetti sauce submarine sandwich',
#  'Chiliburger',
#  'Corned beef sandwich',
#  'Reuben sandwich',
#  'Pastrami sandwich',
#  'Roast beef sandwich',
#  'Roast beef submarine sandwich',
#  'Roast beef sandwich with cheese',
#  'Roast beef sandwich with bacon and cheese sauce',
#  'Steak submarine sandwich with lettuce and tomato',
#  'Steak sandwich',
#  'Steak and cheese submarine sandwich',
#  'Steak and cheese sandwich',
#  'Fajita-style beef sandwich with cheese',
#  'Gyro sandwich (pita bread',
#  'Hamburger wrap sandwich',
#  'Bacon sandwich',
#  'Bacon and cheese sandwich',
#  'Bacon and egg sandwich',
#  'Bacon on biscuit',
#  'Ham on biscuit',
#  'Ham sandwich',
#  'Ham sandwich with lettuce and spread',
#  'Ham and cheese sandwich',
#  'Ham salad sandwich',
#  'Hot ham and cheese sandwich',
#  'Ham and cheese on English muffin',
#  'Ham and cheese submarine sandwich',
#  'Cuban sandwich',
#  'Midnight sandwich',
#  'Pork sandwich',
#  'Pork barbecue sandwich or Sloppy Joe',
#  'Sliced chicken sandwich',
#  'Chicken salad or chicken spread sandwich',
#  'Chicken barbecue sandwich',
#  'Chicken fillet sandwich',
#  'Chicken fillet biscuit',
#  'Chicken fillet wrap sandwich',
#  'Chicken submarine sandwich',
#  'Buffalo chicken submarine sandwich',
#  'Buffalo chicken submarine sandwich with cheese',
#  'Turkey sandwich',
#  'Turkey salad or turkey spread sandwich',
#  'Turkey submarine sandwich',
#  'Turkey and bacon submarine sandwich',
#  'Turkey or chicken burger',
#  'Fish sandwich',
#  'Crab cake sandwich',
#  'Salmon cake sandwich',
#  'Fried seafood sandwich',
#  'Fish wrap sandwich',
#  'Sardine sandwich',
#  'Tuna salad sandwich',
#  'Tuna salad wrap sandwich',
#  'Seafood salad sandwich',
#  'Luncheon meat sandwich',
#  'Bologna sandwich',
#  'Bologna and cheese sandwich',
#  'Corn dog',
#  'Pig in a blanket',
#  'Puerto Rican sandwich',
#  'Pepperoni and salami submarine sandwich',
#  'Salami sandwich',
#  'Sausage on biscuit',
#  'Sausage griddle cake sandwich',
#  'Sausage and cheese on English muffin',
#  'Sausage balls',
#  'Sausage sandwich',
#  'Sausage and spaghetti sauce sandwich',
#  'Cold cut sumarine sandwich',
#  'Meat spread or potted meat sandwich',
#  'Frankfurter or hot dog sandwich',
#  "Hors d'oeuvres",
#  'Beef and egg noodles',
#  'Beef with vegetables',
#  'Chicken and rice dinner',
#  'Chicken noodle dinner',
#  'Chicken stew',
#  'Chicken soup',
#  'Frozen dinner',
#  'Beef dinner',
#  'Beef with vegetable',
#  'Sirloin',
#  'Sirloin tips',
#  'Sirloin beef',
#  'Salisbury steak dinner',
#  'Salisbury steak',
#  'Beef short ribs',
#  'Beef with spaetzle or rice',
#  'Chicken dinner',
#  'Chicken and noodles with vegetable',
#  'Chicken patty or nuggets',
#  'Teriyaki chicken with rice and vegetable',
#  'Chicken with rice and vegetable',
#  'Chicken and vegetables au gratin with rice',
#  'Chicken and vegetable entree with rice',
#  'Chicken chow mein with rice',
#  'Chicken with noodles and cheese sauce',
#  'Chicken and vegetable entree with noodles',
#  'Chicken in cream sauce with noodles and vegetable',
#  'Chicken in butter sauce with potatoes and vegetable',
#  'Chicken in mushroom sauce',
#  'Chicken in soy-based sauce',
#  'Chicken and vegetable entree with noodles and cream sauce',
#  'Turkey dinner',
#  'Turkey with vegetable',
#  'Flounder with chopped broccoli',
#  'Fish in lemon-butter sauce with starch item',
#  'Shrimp and clams in tomato-based sauce',
#  'Shrimp and vegetables in sauce with noodles',
#  'Meat loaf dinner',
#  'Meat loaf with potatoes',
#  'Oxtail soup',
#  'Beef broth',
#  'Meatball soup',
#  'Beef noodle soup',
#  'Pho',
#  'Beef and rice soup',
#  'Pepperpot soup',
#  'Menudo soup',
#  'Beef vegetable soup with potato',
#  'Beef vegetable soup',
#  'Meat and corn hominy soup',
#  'Italian Wedding Soup',
#  'Beef stroganoff soup',
#  'Pork vegetable soup with potato',
#  'Bacon soup',
#  'Chicken or turkey broth',
#  'Mexican style chicken broth soup stock',
#  'Chicken rice soup',
#  'Chicken soup with noodles and potatoes',
#  'Chicken or turkey gumbo soup',
#  'Chicken or turkey noodle soup',
#  'Sweet and sour soup',
#  'Chicken or turkey soup with vegetables',
#  'Chicken or turkey corn soup with noodles',
#  'Chicken or turkey vegetable soup',
#  'Chicken or turkey vegetable soup with rice',
#  'Chicken or turkey vegetable soup with noodles',
#  'Chicken or turkey and corn hominy soup',
#  'Chicken or turkey vegetable soup with potato and cheese',
#  "Bird's nest soup",
#  'Hot and sour soup',
#  'Chicken or turkey soup with vegetables and fruit',
#  'Chicken or turkey soup',
#  'Chicken or turkey mushroom soup',
#  'Fish stock',
#  'Fish chowder',
#  'Crab soup',
#  'Clam chowder',
#  'Turtle and vegetable soup',
#  'Fish and vegetable soup',
#  'Fish soup with potatoes',
#  'Codfish',
#  'Codfish soup with noodles',
#  'Lobster bisque',
#  'Lobster gumbo',
#  'Oyster stew',
#  'Salmon soup',
#  'Shrimp soup',
#  'Shrimp gumbo',
#  'Seafood soup with potatoes and vegetables including carrots',
#  'Seafood soup with potatoes',
#  'Meat broth',
#  'Spanish vegetable soup',
#  'Gravy',
#  'Oyster sauce',
#  'Mole sauce',
#  'Egg',
#  'Duck egg',
#  'Goose egg',
#  'Quail egg',
#  'Egg salad',
#  'Egg Salad',
#  'Huevos rancheros',
#  'Egg casserole with bread',
#  'Egg foo yung',
#  'Chicken egg foo yung',
#  'Pork egg foo yung',
#  'Shrimp egg foo yung',
#  'Beef egg foo yung',
#  'Ripe plantain omelet',
#  'Scrambled eggs with jerked beef',
#  'Eggs a la Malaguena',
#  'Shrimp-egg patty',
#  'Egg omelet or scrambled egg',
#  'Egg and sausage on biscuit',
#  'Egg and bacon on biscuit',
#  'Egg and ham on biscuit',
#  'Egg and steak on biscuit',
#  'Egg and cheese on biscuit',
#  'Egg salad sandwich',
#  'Scrambled egg sandwich',
#  'Egg drop soup',
#  'Garlic egg soup',
#  'Egg white omelet',
#  'Egg white',
#  'Meringues',
#  'Egg substitute',
#  'Beans',
#  'White beans',
#  'Black beans',
#  'Black beans with meat',
#  'Fava beans',
#  'Lima beans',
#  'Pink beans',
#  'Pinto beans',
#  'Pinto beans with meat',
#  'Kidney beans',
#  'Kidney beans with meat',
#  'Peruvian beans',
#  'Soybeans',
#  'Mung beans',
#  'Baked beans',
#  'Baked beans from fast food / restaurant',
#  'Beans and tomatoes',
#  'Black bean salad',
#  'Refried beans',
#  'Refried beans with meat',
#  'Bean dip',
#  'Layer dip',
#  'Hummus',
#  'Black bean sauce',
#  'Beans and franks',
#  'Pork and beans',
#  'Beans with meat',
#  'Falafel',
#  'Bean cake',
#  'Chili with beans',
#  'Blackeyed peas',
#  'Chickpeas',
#  'Split peas',
#  'Wasabi peas',
#  'Lentils',
#  'Bean chips',
#  'Papad',
#  'Sambar',
#  'Lentil curry',
#  'Lentil curry with rice',
#  'Soy nuts',
#  'Soy chips',
#  'Soybean curd',
#  'Edamame',
#  'Soybean curd cheese',
#  'Miso sauce',
#  'Miso',
#  'Natto',
#  'Hoisin sauce',
#  'Soy sauce',
#  'Teriyaki sauce',
#  'Worcestershire sauce',
#  'Vermicelli',
#  'Textured vegetable protein',
#  'Frozen dessert',
#  'Bean soup',
#  'Bean with bacon or ham soup',
#  'Black bean soup',
#  'Lima bean soup',
#  'Soybean soup',
#  'Pinto bean soup',
#  'Bean and ham soup',
#  'Liquid from stewed kidney beans',
#  'Pea and ham soup',
#  'Garbanzo bean or chickpea soup',
#  'Split pea and ham soup',
#  'Split pea soup',
#  'Lentil soup',
#  'Bacon strip',
#  'Bacon bits',
#  'Breakfast link',
#  'Luncheon slice',
#  'Meatball',
#  'Vegetarian burger or patty',
#  'Sandwich spread',
#  'Vegetarian pot pie',
#  'Vegetarian chili',
#  'Vegetarian',
#  'Vegetarian stew',
#  'Vegetarian stroganoff',
#  'Soyburger',
#  'Nuts',
#  'Almonds',
#  'Brazil nuts',
#  'Cashews',
#  'Chestnuts',
#  'Coconut',
#  'Hazelnuts',
#  'Macadamia nuts',
#  'Mixed nuts',
#  'Peanuts',
#  'Pecans',
#  'Pine nuts',
#  'Pistachio nuts',
#  'Walnuts',
#  'Almond butter',
#  'Almond paste',
#  'Cashew butter',
#  'Peanut butter',
#  'Peanut butter and jelly',
#  'Peanut butter and chocolate spread',
#  'Soy nut butter',
#  'Peanut sauce',
#  'Peanut butter sandwich',
#  'Peanut butter and jelly sandwich',
#  'Coconut cream',
#  'Coconut water',
#  'Trail mix',
#  'Trail mix with nuts',
#  'Trail mix with nuts and fruit',
#  'Trail mix with chocolate',
#  'Trail mix with pretzels',
#  'Pumpkin seeds',
#  'Sunflower seeds',
#  'Sesame seeds',
#  'Tahini',
#  'Flax seeds',
#  'Mixed seeds',
#  'Chia seeds',
#  'Carob chips',
#  'Bread',
#  'Roll',
#  'Focaccia',
#  'Naan',
#  'Garlic bread',
#  'Bruschetta',
#  'Pan Dulce',
#  'Coffee cake',
#  'Croissant',
#  'Brioche',
#  'Bagel',
#  'Bread stuffing',
#  'Bread stuffing made with egg',
#  'Breadsticks',
#  'Croutons',
#  'Muffin',
#  'Melba toast',
#  ...]

# %% [markdown]
# ## NO EJECUTAR DE NUEVO
# Traducir la variable categorias para que el LLM busque en categoria por esas variables en de inventarse el nombre

# %%
# import time
# import ast

# translator_system_prompt_bulk = SystemMessagePromptTemplate.from_template(
#     """Eres un traductor experto. Tu tarea es traducir una lista de categorías de alimentos del inglés al español.
#     Para cada categoría, proporciona la traducción más común y útil para identificar ese tipo de alimento en una consulta en español.
#     Devuelve las traducciones como una lista de strings de Python, donde cada string es la traducción en español de una categoría.
#     Asegúrate de que la salida sea un string que represente una lista de Python válida, sin ningún texto adicional o explicaciones.

#     Ejemplo de entrada:
#     - "Milk"
#     - "Meats and Poultry"
#     - "Fresh Fruits"

#     Ejemplo de salida:
#     ["Leche", "Carnes y Aves", "Frutas Frescas"]

#     Asegúrate de manejar categorías compuestas correctamente y de usar la capitalización o el formato más natural para un nombre de alimento/categoría en español.
#     Si una categoría ya parece ser una palabra en español, devuélvela tal cual, a menos que haya una traducción más común.
#     """
# )
# translator_human_prompt_bulk = HumanMessagePromptTemplate.from_template("Traduce las siguientes categorías:\n{categories_list_english}")
# translator_prompt_bulk = ChatPromptTemplate.from_messages([
#     translator_system_prompt_bulk,
#     translator_human_prompt_bulk
# ])
# translator_chain_bulk = LLMChain(llm=llm, prompt=translator_prompt_bulk)

# # --- 3. Función para dividir lista en lotes (chunks) ---
# def chunk_list(data, chunk_size):
#     for i in range(0, len(data), chunk_size):
#         yield data[i:i + chunk_size]
        

# all_translated_categories_es = [] # Lista para recolectar todas las traducciones
    
# BATCH_SIZE = 100 
# SLEEP_TIME_SECONDS = 5 

# print(f"Total de categorías a traducir: {len(unique_categories)}")
# print(f"Procesando en lotes de {BATCH_SIZE} con {SLEEP_TIME_SECONDS} segundos de espera entre lotes.")

# batches = list(chunk_list(unique_categories, BATCH_SIZE))
# total_batches = len(batches)

# for i, batch in enumerate(batches):
#     print(f"\nProcesando lote {i+1}/{total_batches} (elementos {i*BATCH_SIZE + 1} a {(i+1)*BATCH_SIZE} de {len(unique_categories)})...")
    
#     # Formatear el lote actual para el prompt del LLM
#     categories_for_prompt = "\n".join([f"- \"{cat}\"" for cat in batch])

#     try:
#         start_time = time.time()
#         # Llamada al LLM para el lote actual
#         translated_categories_str = translator_chain_bulk.run(
#             categories_list_english=categories_for_prompt
#         ).strip()
#         end_time = time.time()
#         print(f"Llamada al LLM del lote {i+1} completada en {end_time - start_time:.2f} segundos.")

#         # Parsear el string de Python list y añadirlo a la lista global
#         current_batch_translations = ast.literal_eval(translated_categories_str)
#         all_translated_categories_es.extend(current_batch_translations)
#         print(f"Traducciones añadidas del lote {i+1}: {len(current_batch_translations)}.")

#     except Exception as e:
#         print(f"ERROR al traducir lote {i+1}: {e}")
#         print("Saltando este lote. El proceso continuará con el siguiente. Revisa el error y considera reintentar este lote manualmente.")
#         # Si un lote falla, no detenemos todo, pero guardaremos lo que se ha podido hacer.
#         # Puedes implementar una lógica más sofisticada aquí si necesitas reintentos.

#     # Pausar entre lotes para evitar límites de tasa de la API del LLM
#     if i < total_batches - 1:
#         print(f"Esperando {SLEEP_TIME_SECONDS} segundos antes del siguiente lote...")
#         time.sleep(SLEEP_TIME_SECONDS)
# Out:
# Total de categorías a traducir: 2380
# Procesando en lotes de 100 con 5 segundos de espera entre lotes.
#
# Procesando lote 1/24 (elementos 1 a 100 de 2380)...
# C:\Users\asusg\AppData\Local\Temp\ipykernel_20592\3058728298.py:55: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   translated_categories_str = translator_chain_bulk.run(
# Llamada al LLM del lote 1 completada en 5.90 segundos.
# Traducciones añadidas del lote 1: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 2/24 (elementos 101 a 200 de 2380)...
# Llamada al LLM del lote 2 completada en 7.03 segundos.
# Traducciones añadidas del lote 2: 99.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 3/24 (elementos 201 a 300 de 2380)...
# Llamada al LLM del lote 3 completada en 7.37 segundos.
# Traducciones añadidas del lote 3: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 4/24 (elementos 301 a 400 de 2380)...
# Llamada al LLM del lote 4 completada en 10.82 segundos.
# Traducciones añadidas del lote 4: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 5/24 (elementos 401 a 500 de 2380)...
# Llamada al LLM del lote 5 completada en 10.16 segundos.
# Traducciones añadidas del lote 5: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 6/24 (elementos 501 a 600 de 2380)...
# Llamada al LLM del lote 6 completada en 10.23 segundos.
# Traducciones añadidas del lote 6: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 7/24 (elementos 601 a 700 de 2380)...
# Llamada al LLM del lote 7 completada en 7.23 segundos.
# Traducciones añadidas del lote 7: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 8/24 (elementos 701 a 800 de 2380)...
# Llamada al LLM del lote 8 completada en 11.09 segundos.
# Traducciones añadidas del lote 8: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 9/24 (elementos 801 a 900 de 2380)...
# Llamada al LLM del lote 9 completada en 9.68 segundos.
# Traducciones añadidas del lote 9: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 10/24 (elementos 901 a 1000 de 2380)...
# Llamada al LLM del lote 10 completada en 8.93 segundos.
# Traducciones añadidas del lote 10: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 11/24 (elementos 1001 a 1100 de 2380)...
# Llamada al LLM del lote 11 completada en 7.76 segundos.
# Traducciones añadidas del lote 11: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 12/24 (elementos 1101 a 1200 de 2380)...
# Llamada al LLM del lote 12 completada en 11.14 segundos.
# Traducciones añadidas del lote 12: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 13/24 (elementos 1201 a 1300 de 2380)...
# Llamada al LLM del lote 13 completada en 12.91 segundos.
# Traducciones añadidas del lote 13: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 14/24 (elementos 1301 a 1400 de 2380)...
# Llamada al LLM del lote 14 completada en 10.01 segundos.
# Traducciones añadidas del lote 14: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 15/24 (elementos 1401 a 1500 de 2380)...
# Llamada al LLM del lote 15 completada en 9.57 segundos.
# Traducciones añadidas del lote 15: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 16/24 (elementos 1501 a 1600 de 2380)...
# Llamada al LLM del lote 16 completada en 7.58 segundos.
# Traducciones añadidas del lote 16: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 17/24 (elementos 1601 a 1700 de 2380)...
# Llamada al LLM del lote 17 completada en 9.41 segundos.
# Traducciones añadidas del lote 17: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 18/24 (elementos 1701 a 1800 de 2380)...
# Llamada al LLM del lote 18 completada en 7.42 segundos.
# Traducciones añadidas del lote 18: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 19/24 (elementos 1801 a 1900 de 2380)...
# Llamada al LLM del lote 19 completada en 7.20 segundos.
# Traducciones añadidas del lote 19: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 20/24 (elementos 1901 a 2000 de 2380)...
# Llamada al LLM del lote 20 completada en 5.87 segundos.
# Traducciones añadidas del lote 20: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 21/24 (elementos 2001 a 2100 de 2380)...
# Llamada al LLM del lote 21 completada en 5.92 segundos.
# Traducciones añadidas del lote 21: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 22/24 (elementos 2101 a 2200 de 2380)...
# Llamada al LLM del lote 22 completada en 5.72 segundos.
# Traducciones añadidas del lote 22: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 23/24 (elementos 2201 a 2300 de 2380)...
# Llamada al LLM del lote 23 completada en 8.40 segundos.
# Traducciones añadidas del lote 23: 100.
# Esperando 5 segundos antes del siguiente lote...
#
# Procesando lote 24/24 (elementos 2301 a 2400 de 2380)...
# Llamada al LLM del lote 24 completada en 8.99 segundos.
# Traducciones añadidas del lote 24: 80.

# %% [markdown]
# Categorias traducidas guardadas en un archivo JSON para no ejecutar cada vez

# %%
# import json

# file_name = "specific_food_translations.json"
# file_path = f"./data/csv/{file_name}"
# with open(file_path, 'w', encoding='utf-8') as f:
#     json.dump(all_translated_categories_es, f, ensure_ascii=False, indent=4)
# print(f"Traducciones guardadas en {file_path}")
# Out:
# Traducciones guardadas en ./data/csv/specific_food_translations.json

# %%
import json
import os

file_name = "specific_food_translations.json"
file_path = f"../data/csv/{file_name}"
all_translated_categories_es = []

if os.path.exists(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        all_translated_categories_es = json.load(f)
    print(f"Traducciones cargadas desde {file_path} ({len(all_translated_categories_es)} términos).")
else:
    print(f"Archivo {file_path} no encontrado. Generando traducciones...")
# Out:
# Traducciones cargadas desde ../data/csv/specific_food_translations.json (2379 términos).

# %%
def resolver_sql(pregunta):
    contexto_pistas = ""
    pregunta_normalizada = pregunta.lower()

    # 1. Identificar si es una pregunta general o específica
    # Una forma simple es buscar si la pregunta contiene términos de "propiedad general"
    # que no suelen ir acompañados de un alimento específico.
    general_property_keywords = [
        "calorias", "carbohidratos", "colesterol", "colina", "fibra", "niacina", 
        "proteina", "retinol", "riboflavina", "selenio", "azucar total", "tiamina", 
        "agua", "grasa monosaturada", "grasa polisaturada", "grasa saturada", 
        "lipido total", "calcio", "cobre", "hierro", "magnesio", "fosforo", 
        "potasio", "sodio", "zinc", "vitamina a", "vitamina b12", "vitamina b6", 
        "vitamina c", "vitamina e", "vitamina k", "alfa caroteno", "beta caroteno", 
        "beta criptoxantina", "luteina y zeaxantina", "licopeno"
    ]    # Si la pregunta contiene alguna de estas palabras clave Y NO contiene un nombre de alimento específico
    # (como aguacate, pollo, etc.), la consideramos "general".
    
    # Simplificamos la detección de pregunta específica basándonos en la aparición de nombres de alimentos traducibles
    # Si la traducción de la frase completa contiene un nombre de alimento claro, es específica.
    
    # Intenta traducir la pregunta completa para obtener un término que pueda usarse en `LIKE`
    translated_phrase = ""
    try:
        translated_phrase = translator_chain.run(term_spanish=pregunta).strip()
        print(f"Frase traducida para búsqueda: '{translated_phrase}'")
    except Exception as e:
        print(f"Error al traducir la pregunta completa: {e}")

    # Lista de nombres de alimentos clave en inglés (CamelCase)
    # que, si están en la pregunta traducida, implican una búsqueda específica.
    specific_food_translations = unique_categories 
    
    is_specific_food_query = False
    for food_term in specific_food_translations:
        if food_term.lower() in translated_phrase.lower():
            is_specific_food_query = True
            break
            
    # Si la pregunta es sobre una propiedad general (ej. "menos de X calorías")
    # Y no se detecta un alimento específico en la pregunta, la tratamos como general.
    # Esto ayuda a que no se inyecten filtros de categoría/descripción irrelevantes.
    is_general_numeric_query = any(keyword in pregunta_normalizada for keyword in general_property_keywords) and not is_specific_food_query
    
    pregunta_procesada = pregunta

    # --- Lógica de fuzzy matching y determinación de pistas ---
    matched_categories_for_llm = []
    matched_descriptions_for_llm = []

    # Búsqueda en CATEGORIES
    # Solo añadir categorías si es una consulta sobre un alimento específico
    if is_specific_food_query:
        for cat_db in unique_categories:
            # Coincidencia directa del nombre de la categoría con la pregunta traducida o original
            if cat_db.lower() in translated_phrase.lower() or cat_db.lower() in pregunta_normalizada:
                if cat_db not in matched_categories_for_llm:
                    matched_categories_for_llm.append(cat_db)
            
            # Fuzzy matching para categorías (puedes ajustar el umbral)
            cat_display_name_for_fuzzy = ' '.join([word.capitalize() for word in cat_db.replace('.', ' ').split()])
            matches_cat = process.extract(translated_phrase.lower(), [cat_display_name_for_fuzzy.lower()], limit=1, scorer=process.fuzz.token_set_ratio)
            if matches_cat and matches_cat[0][1] > 90: # Umbral alto para evitar falsos positivos como "Lime"
                 if cat_db not in matched_categories_for_llm:
                    matched_categories_for_llm.append(cat_db)
                    
    # Las descripciones relevantes provienen de la traducción de la frase completa
    # y los términos específicos si se identificaron.
    # Solo añadir descripciones LIKE si es una consulta de alimento específico.
    if is_specific_food_query and translated_phrase:
        # Añade la traducción CamelCase de la frase completa como una pista de descripción
        # si contiene un término de alimento específico y no es una propiedad genérica.
        camel_case_translated_phrase = ' '.join([word.capitalize() for word in translated_phrase.split()])
        if camel_case_translated_phrase not in matched_descriptions_for_llm:
            matched_descriptions_for_llm.append(camel_case_translated_phrase)

    # --- Construcción del contexto de pistas inteligentemente ---
    contexto_pistas = ""
    
    if is_specific_food_query:
        if matched_categories_for_llm:
            matched_categories_unique = list(set(matched_categories_for_llm))
            # Opcional: Limitar el número de categorías para no sobrecargar el prompt
            if len(matched_categories_unique) > 3: 
                matched_categories_unique = matched_categories_unique[:3] 
            contexto_pistas += f"El usuario podría referirse a las siguientes categorías: {', '.join(matched_categories_unique)}. "
            
        if matched_descriptions_for_llm:
            matched_descriptions_unique = list(set(matched_descriptions_for_llm))
            # Opcional: Limitar el número de descripciones para no sobrecargar el prompt
            if len(matched_descriptions_unique) > 5:
                 matched_descriptions_unique = matched_descriptions_unique[:5] 
            # Damos una pista fuerte al LLM para que use estos términos en LIKE
            contexto_pistas += f"El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): {', '.join(matched_descriptions_unique)}. "
    
    # Para preguntas generales, no inyectamos pistas de categoría/descripción de alimentos,
    # el LLM debe usar las propiedades numéricas directamente.
    # La directriz 2 del prompt de SQL es crucial aquí.
    # No es necesario un 'else' explícito, si las listas están vacías, contexto_pistas quedará vacío.

    if contexto_pistas:
        print(f"Pistas inyectadas: {contexto_pistas}")
    else:
        print("No se inyectaron pistas de categoría/descripción.")


    # Paso 1: usar el LLM para generar la SQL a partir de la pregunta, pasando el contexto y la pregunta procesada
    consulta_sql = sql_chain.run(
        pregunta=pregunta, # Usamos la pregunta original para el LLM de SQL
        contexto=contexto_pistas # Las pistas se inyectan aquí
    ).strip()
    
    # Esto actúa como una salvaguarda en caso de que el LLM aún intente añadir el formato.
    if consulta_sql.startswith('```sql\n') and consulta_sql.endswith('\n```'):
        consulta_sql = consulta_sql[len('```sql\n'):-len('\n```')].strip()
    elif consulta_sql.startswith('```') and consulta_sql.endswith('```'):
        consulta_sql = consulta_sql[len('```'):-len('```')].strip()
        
    print(f"SQL generada:\n{consulta_sql}\n")

    # Paso 2: ejecutar la consulta sobre la base de datos SQLite
    try:
        conn = sqlite3.connect(DATABASE_PATH)
        resultado = pd.read_sql_query(consulta_sql, conn)
        print(resultado)
        return resultado
    except Exception as e:
        return f"Error al ejecutar la consulta:\n{e}"
    finally:
        if conn:
            conn.close()

# %%
import time

# %%
preguntas = ["¿Qué alimentos tienen menos de 10 calorias, dime los 5 con menos?",
            "¿Cuántas calorías tiene un aguacate?",
            "¿Cuántos gramos de proteína hay en 100g de pechuga de pollo? Devuelve 5",
            "¿Cuál es el contenido de hierro en las lentejas? Devuelve 5",
            "Dime los microgramos de Vitamina B12 que tiene el salmón. Devuelve 5",
            "Enumera los 5 alimentos con más potasio de tu base de datos.",
            "¿Qué tiene más grasa saturada, el queso cheddar o la mantequilla?"
]

for pregunta in preguntas:
    print(f"Pregunta: {pregunta}")
    resolver_sql(pregunta)
    time.sleep(1)
# Out:
# Pregunta: ¿Qué alimentos tienen menos de 10 calorias, dime los 5 con menos?
# Frase traducida para búsqueda: 'Low-calorie foods'
# No se inyectaron pistas de categoría/descripción.
# SQL generada:
# SELECT "category", "description", "calories" FROM comida WHERE "calories" < 10 ORDER BY "calories" ASC LIMIT 5;
#
#   category                                        description  calories
# 0      Tea               Tea, hot, leaf, green, decaffeinated       0.0
# 1      Tea             Tea, iced, instant, green, unsweetened       0.0
# 2      Tea                                 Tea, hot, hibiscus       0.0
# 3      Tea  Tea, iced, brewed, green, decaffeinated, unswe...       0.0
# 4      Tea             Tea, iced, bottled, black, unsweetened       0.0
# Pregunta: ¿Cuántas calorías tiene un aguacate?
# Frase traducida para búsqueda: 'avocado'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Avocado, Avocado dressing. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Avocado.
# SQL generada:
# SELECT "category", "description", "calories" FROM comida WHERE "description" LIKE '%Avocado%';
#
#            category                                        description  \
# 0        Sushi roll                                Sushi roll, avocado
# 1           Avocado                                       Avocado, raw
# 2           Lettuce  Lettuce, salad with avocado, tomato, and/or ca...
# 3  Avocado dressing                                   Avocado dressing
# 4           Avocado                     Avocado, for use on a sandwich
#
#    calories
# 0     91.31
# 1    174.06
# 2     57.19
# 3    427.01
# 4    174.06
# Pregunta: ¿Cuántos gramos de proteína hay en 100g de pechuga de pollo? Devuelve 5
# Frase traducida para búsqueda: 'chicken breast'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Chicken, Chicken breast. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Chicken Breast.
# SQL generada:
# SELECT "category", "description", "protein" FROM comida WHERE "description" LIKE '%Chicken Breast%' LIMIT 5;
#
#          category                                        description  protein
# 0  Chicken breast  Chicken breast, NS as to cooking method, skin ...    26.37
# 1  Chicken breast  Chicken breast, NS as to cooking method, skin ...    28.04
# 2  Chicken breast  Chicken breast, baked, broiled, or roasted, sk...    26.25
# 3  Chicken breast  Chicken breast, baked, broiled, or roasted, sk...    30.22
# 4  Chicken breast  Chicken breast, baked or broiled, skin eaten, ...    26.37
# Pregunta: ¿Cuál es el contenido de hierro en las lentejas? Devuelve 5
# Frase traducida para búsqueda: 'lentils'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Lentils, Pasta with tomato-based sauce and beans or lentils. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Lentils.
# SQL generada:
# SELECT "category", "description", "major_minerals.iron" FROM comida WHERE "description" LIKE '%Lentils%' LIMIT 5;
#
#                                             category  \
# 0                                            Lentils
# 1                                            Lentils
# 2                                            Lentils
# 3                                            Lentils
# 4  Pasta with tomato-based sauce and beans or len...
#
#                                          description  major_minerals.iron
# 0                                       Lentils, NFS                 3.11
# 1                     Lentils, from dried, fat added                 3.11
# 2                  Lentils, from dried, no added fat                 3.31
# 3                               Lentils, from canned                 3.10
# 4  Pasta with tomato-based sauce and beans or len...                 1.73
# Pregunta: Dime los microgramos de Vitamina B12 que tiene el salmón. Devuelve 5
# Frase traducida para búsqueda: 'Salmon'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Salmon salad, Lomi salmon, Salmon loaf. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Salmon.
# SQL generada:
# SELECT "category", "description", "vitamins.vitamin_b12" FROM comida WHERE "description" LIKE '%Salmon%' LIMIT 5;
#
#   category                                    description  \
# 0   Salmon                                    Salmon, raw
# 1   Salmon        Salmon, cooked, NS as to cooking method
# 2   Salmon        Salmon, baked or broiled, made with oil
# 3   Salmon     Salmon, baked or broiled, made with butter
# 4   Salmon  Salmon, baked or broiled, made with margarine
#
#    vitamins.vitamin_b12
# 0                  4.15
# 1                  4.57
# 2                  4.57
# 3                  4.57
# 4                  4.57
# Pregunta: Enumera los 5 alimentos con más potasio de tu base de datos.
# Frase traducida para búsqueda: 'Potassium-rich foods'
# No se inyectaron pistas de categoría/descripción.
# SQL generada:
# SELECT "category", "description", "major_minerals.potassium" FROM comida ORDER BY "major_minerals.potassium" DESC LIMIT 5;
#
#              category                                        description  \
# 0                 Tea        Tea, iced, instant, black, unsweetened, dry
# 1              Coffee                 Coffee, instant, not reconstituted
# 2              Coffee  Coffee, instant, 50% less caffeine, not recons...
# 3              Coffee  Coffee, instant, decaffeinated, not reconstituted
# 4  Sun-dried tomatoes                                 Sun-dried tomatoes
#
#    major_minerals.potassium
# 0                    6040.0
# 1                    3535.0
# 2                    3535.0
# 3                    3501.0
# 4                    3427.0
# Pregunta: ¿Qué tiene más grasa saturada, el queso cheddar o la mantequilla?
# Frase traducida para búsqueda: 'cheddar cheese'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Cheese, Cheddar cheese soup. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Cheddar Cheese.
# SQL generada:
# SELECT "category", "description", "fat.saturated_fat" FROM comida WHERE "description" LIKE '%Cheddar Cheese%' OR "description" LIKE '%Butter%' ORDER BY "fat.saturated_fat" DESC LIMIT 1;
#
#   category             description  fat.saturated_fat
# 0     Ghee  Ghee, clarified butter             61.924

# %%
preguntas = [
    "¿Qué alimentos tienen más de 70 gramos de carbohidratos y menos de 50 gramos de grasa saturada? Devuelve 5",
    "Que alimentos tienen menos grasas saturadas y más proteinas, devuelve 5",
    "¿Cuántas calorías tiene una manzana? Devuelve 2"
]

for pregunta in preguntas:
    print(f"Pregunta: {pregunta}")
    resolver_sql(pregunta)
    time.sleep(1)
# Out:
# Pregunta: ¿Qué alimentos tienen más de 70 gramos de carbohidratos y menos de 50 gramos de grasa saturada? Devuelve 5
# Frase traducida para búsqueda: 'carbohydrates'
# No se inyectaron pistas de categoría/descripción.
# SQL generada:
# SELECT "category", "description", "carbohydrate", "fat.saturated_fat" FROM comida WHERE "carbohydrate" > 70 AND "fat.saturated_fat" < 50 LIMIT 5;
#
#                      category  \
# 0                        Whey
# 1   Chocolate beverage powder
# 2                        Milk
# 3  Strawberry beverage powder
# 4              Coffee creamer
#
#                                          description  carbohydrate  \
# 0                                   Whey, sweet, dry         74.46
# 1  Chocolate beverage powder, dry mix, not recons...         90.28
# 2           Milk, malted, dry mix, not reconstituted         92.96
# 3  Strawberry beverage powder, dry mix, not recon...         99.10
# 4                   Coffee creamer, powder, flavored         75.42
#
#    fat.saturated_fat
# 0              0.684
# 1              2.273
# 2              0.000
# 3              0.000
# 4             19.446
# Pregunta: Que alimentos tienen menos grasas saturadas y más proteinas, devuelve 5
# Frase traducida para búsqueda: 'Lean meats'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Meat, Lime. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Lean Meats.
# SQL generada:
# SELECT "category", "description", "fat.saturated_fat", "protein" FROM comida WHERE "description" LIKE '%Lean Meats%' ORDER BY "fat.saturated_fat" ASC, "protein" DESC LIMIT 5;
#
# Empty DataFrame
# Columns: [category, description, fat.saturated_fat, protein]
# Index: []
# Pregunta: ¿Cuántas calorías tiene una manzana? Devuelve 2
# Frase traducida para búsqueda: 'apple'
# Pistas inyectadas: El usuario podría referirse a las siguientes categorías: Apple salad with dressing, Apple-peach juice, Apple-cherry juice. El usuario podría referirse a alimentos con estas descripciones (usa LIKE con los términos ya en inglés CamelCase): Apple.
# SQL generada:
# SELECT "category", "description", "calories" FROM comida WHERE "description" LIKE '%Apple%';
#
#                                              category  \
# 0                                            Scrapple
# 1                                     Cake or cupcake
# 2                                     Cake or cupcake
# 3                                                Cake
# 4                                              Cookie
# ..                                                ...
# 90                                            Carrots
# 91  Cabbage salad or coleslaw with apples and/or r...
# 92           Cabbage salad or coleslaw with pineapple
# 93                                    Pineapple candy
# 94                               Apple juice beverage
#
#                                           description  calories
# 0                                    Scrapple, cooked    226.96
# 1   Cake or cupcake, applesauce, without icing or ...    419.96
# 2   Cake or cupcake, applesauce, with icing or fil...    435.55
# 3                        Cake, pineapple, upside down    336.92
# 4                                  Cookie, applesauce    462.50
# ..                                                ...       ...
# 90                    Carrots, raw, salad with apples    179.55
# 91  Cabbage salad or coleslaw with apples and/or r...    113.86
# 92  Cabbage salad or coleslaw with pineapple, with...    107.33
# 93                Pineapple candy, Puerto Rican style    345.37
# 94          Apple juice beverage, 40-50% juice, light     21.30
#
# [95 rows x 3 columns]

# %% [markdown]
# ### Routing por inferencia con LLM

# %%
from keys import LLM
from langchain.chains import LLMChain
from langchain_core.prompts import ChatPromptTemplate

llm = LLM 

# PROMPT PARA ENRUTAMIENTO (routing)
# Este prompt instruye al modelo para que, dada una pregunta en lenguaje natural, clasifique si debe resolverse con una búsqueda estructurada (SQL)
# o con una búsqueda semántica (RAG).
routing_prompt = ChatPromptTemplate.from_template(
    """Eres un sistema experto que enruta una pregunta de nutrición a la fuente de datos correcta.

Clasifica cada pregunta en una de estas dos opciones:
- "sql" → si la pregunta es sobre la composición nutricional específica de uno o más alimentos. Esto incluye consultas sobre cantidades exactas de nutrientes (ej. gramos de proteína, miligramos de vitamina C), calorías, minerales o grasas en un alimento. También se incluyen comparaciones directas o rankings de alimentos basados en estos datos numéricos.
- "rag" → si la pregunta busca una explicación, recomendación, o información contextual sobre nutrición, suplementación o fitness. Esto abarca preguntas sobre la función de un suplemento (ej. "¿para qué sirve la creatina?"), beneficios, dosis recomendadas, dietas para objetivos específicos (ej. "dieta para diabetes tipo 2"), o consejos basados en un perfil de usuario (ej. "suplementos para un corredor").

Responde únicamente con la palabra: sql o rag.

Pregunta: {pregunta}
"""
)


#Aquí conectamos el prompt anterior con el modelo de lenguaje (llm).
# El resultado es una cadena que puede ejecutarse para obtener el tipo de consulta (sql / mongo).
routing_chain = LLMChain(llm=llm, prompt=routing_prompt)



# Esta función toma una pregunta del usuario y usa el LLM para decidir
# qué tipo de base de datos debe consultarse.
# La salida puede ser "sql", "rag", o un mensaje de error.

def router(pregunta, routing_chain):
    try:
        tipo = routing_chain.invoke({"pregunta": pregunta})["text"].strip().lower()
    except Exception as e:
        return f"Error al decidir la ruta: {e}"

    print(f"Tipo de consulta inferido: {tipo}")

    if tipo == "sql":
        return tipo
        #return resolver_sql(pregunta)
    elif tipo == "rag":
        return tipo
        #return resolver_mongo(pregunta)
    else:
        return f"Ruta desconocida: '{tipo}'"
# Out:
# C:\Users\asusg\AppData\Local\Temp\ipykernel_7624\1159787679.py:27: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   routing_chain = LLMChain(llm=llm, prompt=routing_prompt)

# %% [markdown]
# ### Routing entre BBDD y RAG

# %%
import time

# %%
preguntas_sql = [
    # --- Preguntas claramente SQL ---
    "¿Cuántos gramos de proteína hay en 100g de pechuga de pollo?",
    "¿Cuál es el contenido de hierro en las lentejas?",
    "Dime los microgramos de Vitamina B12 que tiene el salmón.",
    "Enumera los 5 alimentos con más potasio de tu base de datos.",
    "¿Qué tiene más grasa saturada, el queso cheddar o la mantequilla?",
    "¿Cuántas calorías tiene un aguacate?",
]

for pregunta in preguntas_sql:
    tipo = router(pregunta)
    print(f"[{tipo.upper()}] → {pregunta}")
    print("\n")
    time.sleep(1)  # espera 1 segundo entre llamadas
# Out:
# Tipo de consulta inferido: sql
# [SQL] → ¿Cuántos gramos de proteína hay en 100g de pechuga de pollo?
#
#
# Tipo de consulta inferido: sql
# [SQL] → ¿Cuál es el contenido de hierro en las lentejas?
#
#
# Tipo de consulta inferido: sql
# [SQL] → Dime los microgramos de Vitamina B12 que tiene el salmón.
#
#
# Tipo de consulta inferido: sql
# [SQL] → Enumera los 5 alimentos con más potasio de tu base de datos.
#
#
# Tipo de consulta inferido: sql
# [SQL] → ¿Qué tiene más grasa saturada, el queso cheddar o la mantequilla?
#
#
# Tipo de consulta inferido: sql
# [SQL] → ¿Cuántas calorías tiene un aguacate?

# %%
preguntas_rag = [
    # --- Preguntas claramente RAG ---
    "¿Para qué sirve la creatina y cómo se debe tomar?",
    "Explica los beneficios del omega-3 en el rendimiento deportivo.",
    "¿Qué tipo de proteína es mejor para ganar masa muscular?",
    "Soy una mujer de 50 años que hace pesas, ¿qué suplementos me recomiendas para mantener la masa ósea?",
    "¿Qué evidencia hay sobre el uso de la ashwagandha para reducir el cortisol?",
    "¿Cuáles son los principios de una dieta antiinflamatoria?",
]

for pregunta in preguntas_rag:
    tipo = router(pregunta)
    print(f"[{tipo.upper()}] → {pregunta}")
    print("\n")
    time.sleep(1)  # espera 1 segundo entre llamadas
# Out:
# Tipo de consulta inferido: rag
# [RAG] → ¿Para qué sirve la creatina y cómo se debe tomar?
#
#
# Tipo de consulta inferido: rag
# [RAG] → Explica los beneficios del omega-3 en el rendimiento deportivo.
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Qué tipo de proteína es mejor para ganar masa muscular?
#
#
# Tipo de consulta inferido: rag
# [RAG] → Soy una mujer de 50 años que hace pesas, ¿qué suplementos me recomiendas para mantener la masa ósea?
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Qué evidencia hay sobre el uso de la ashwagandha para reducir el cortisol?
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Cuáles son los principios de una dieta antiinflamatoria?

# %%
preguntas_sql_rag = [
    # --- Pares de preguntas (SQL vs RAG) ---
    "¿Qué tiene más hierro, 100g de espinacas o 100g de carne roja?", #SQL
    "¿Por qué es importante el hierro para prevenir la fatiga en atletas?", #RAG
    "Lista 3 tipos de pescado ordenados por su contenido de proteína.", #SQL
    "¿Es mejor tomar la proteína antes o después de entrenar para la recuperación muscular?", #RAG
    "¿Cuántos gramos de azúcar total contiene una manzana?", #SQL
    "Soy diabético tipo 2, ¿qué tipo de carbohidratos debería priorizar en mi dieta?", #RAG
    "¿Cuál es el desglose de grasas (saturadas, mono, poli) del aceite de oliva?", #SQL
    "¿Qué diferencia hay para la salud entre las grasas saturadas y las insaturadas?",  #RAG
]

for pregunta in preguntas_sql_rag:
    tipo = router(pregunta)
    print(f"[{tipo.upper()}] → {pregunta}")
    print("\n")
    time.sleep(1)  # espera 1 segundo entre llamadas
# Out:
# Tipo de consulta inferido: sql
# [SQL] → ¿Qué tiene más hierro, 100g de espinacas o 100g de carne roja?
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Por qué es importante el hierro para prevenir la fatiga en atletas?
#
#
# Tipo de consulta inferido: sql
# [SQL] → Lista 3 tipos de pescado ordenados por su contenido de proteína.
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Es mejor tomar la proteína antes o después de entrenar para la recuperación muscular?
#
#
# Tipo de consulta inferido: sql
# [SQL] → ¿Cuántos gramos de azúcar total contiene una manzana?
#
#
# Tipo de consulta inferido: rag
# [RAG] → Soy diabético tipo 2, ¿qué tipo de carbohidratos debería priorizar en mi dieta?
#
#
# Tipo de consulta inferido: sql
# [SQL] → ¿Cuál es el desglose de grasas (saturadas, mono, poli) del aceite de oliva?
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Qué diferencia hay para la salud entre las grasas saturadas y las insaturadas?

# %%
preguntas_trampa = [
    # --- Preguntas trampa o en el límite ---
    "Quiero saber cuánta fibra tiene la avena y por qué es buena para la digestión.",
    "¿Es saludable el aguacate?",
    "He oído que el magnesio es bueno. ¿Qué alimentos lo contienen y qué suplemento me recomiendas para dormir mejor?"
]

for pregunta in preguntas_trampa:
    tipo = router(pregunta)
    print(f"[{tipo.upper()}] → {pregunta}")
    print("\n")
    time.sleep(1)  # espera 1 segundo entre llamadas
# Out:
# Tipo de consulta inferido: sql
# [SQL] → Quiero saber cuánta fibra tiene la avena y por qué es buena para la digestión.
#
#
# Tipo de consulta inferido: rag
# [RAG] → ¿Es saludable el aguacate?
#
#
# Tipo de consulta inferido: rag
# [RAG] → He oído que el magnesio es bueno. ¿Qué alimentos lo contienen y qué suplemento me recomiendas para dormir mejor?

# %% [markdown]
# ### RESULTADOS
#
# #### --- Preguntas claramente SQL ---
# "¿Cuántos gramos de proteína hay en 100g de pechuga de pollo?",
# "¿Cuál es el contenido de hierro en las lentejas?",
# "Dime los microgramos de Vitamina B12 que tiene el salmón.",
# "Enumera los 5 alimentos con más potasio de tu base de datos.",
# "¿Qué tiene más grasa saturada, el queso cheddar o la mantequilla?",
# "¿Cuántas calorías tiene un aguacate?",
#
# #### --- Preguntas claramente RAG ---
# "¿Para qué sirve la creatina y cómo se debe tomar?",
# "Explica los beneficios del omega-3 en el rendimiento deportivo.",
# "¿Qué tipo de proteína es mejor para ganar masa muscular?",
# "Soy una mujer de 50 años que hace pesas, ¿qué suplementos me recomiendas para mantener la masa ósea?",
# "¿Qué evidencia hay sobre el uso de la ashwagandha para reducir el cortisol?",
# "¿Cuáles son los principios de una dieta antiinflamatoria?",
#
# #### --- Pares de preguntas (SQL vs RAG) ---
# "¿Qué tiene más hierro, 100g de espinacas o 100g de carne roja?" --> SQL,
# "¿Por qué es importante el hierro para prevenir la fatiga en atletas?" --> RAG,
# "Lista 3 tipos de pescado ordenados por su contenido de proteína." --> SQL,
# "¿Es mejor tomar la proteína antes o después de entrenar para la recuperación muscular?" --> RAG,
# "¿Cuántos gramos de azúcar total contiene una manzana?" --> SQL,
# "Soy diabético tipo 2, ¿qué tipo de carbohidratos debería priorizar en mi dieta?" --> RAG,
# "¿Cuál es el desglose de grasas (saturadas, mono, poli) del aceite de oliva?" --> SQL,
# "¿Qué diferencia hay para la salud entre las grasas saturadas y las insaturadas?" --> RAG,
#
# #### --- Preguntas trampa o en el límite ---
# "Quiero saber cuánta fibra tiene la avena y por qué es buena para la digestión."
#
# Resultado esperado: rag. Aunque la primera parte es sql, la segunda ("y por qué es buena") requiere una explicación que solo el RAG puede dar. Un buen sistema debería priorizar la pregunta más compleja.
# ,
#
# "¿Es saludable el aguacate?"
#
# Resultado esperado: rag. La palabra "saludable" es subjetiva. Para responderla, el sistema necesita sintetizar la información nutricional (grasas monoinsaturadas, vitaminas, etc., datos que están en la SQL) y explicar por qué esos componentes son beneficiosos, una tarea propia del RAG.
# ,
#
#
# "He oído que el magnesio es bueno. ¿Qué alimentos lo contienen y qué suplemento me recomiendas para dormir mejor?"
#
# Resultado esperado: rag. La intención principal es una recomendación de suplemento para un fin específico ("dormir mejor"), lo cual es una consulta para el RAG.

# %% [markdown]
# ## Paso final
#
# Hasta ahora ya se tiene el Routing, el sql y el rag. Queda devolver la respuesta personalizada para el usuario.
#
# ```scss
# [Pregunta del usuario]
#         ↓
# [LLM → Routing: sql / mongo]
#         ↓
# ["sql"] → resolver_sql()
# OR
# ["rag"] → resolver_mongo()
#         ↓
# [Contexto recuperado (DataFrame o texto)]
#         ↓
# [LLM: genera una respuesta final personalizada]
#         ↓
# [Respuesta final para el usuario]
# ```
